# %%
# Import packages
import os 
import tensorflow as tf
import skimage.io as skimg
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
#import skimage.io as io

crazing_img = skimg.imread('/Users/jakechiu/Desktop/NEU-DET/image/crazing_1.jpg')
skimg.imshow(crazing_img)
plt.show()

print(crazing_img.shape)

rolled = Image.open('/Users/jakechiu/Desktop/NEU-DET/image/rolled-in_scale_200.jpg')
print(rolled.bits, rolled.size, rolled.format)
# Out:
# (200, 200, 3)
# 8 (200, 200) JPEG

# %%
path = '/Users/jakechiu/Desktop/NEU-DET/image/'
# Find out the name of each picture in IMAGES file
img_name = os.listdir(path)
img_name
# Out:
# ['scratches_225.jpg',
#  'scratches_231.jpg',
#  'scratches_219.jpg',
#  'patches_162.jpg',
#  'pitted_surface_13.jpg',
#  'patches_176.jpg',
#  'patches_189.jpg',
#  'crazing_49.jpg',
#  'crazing_8.jpg',
#  'patches_22.jpg',
#  'crazing_61.jpg',
#  'crazing_75.jpg',
#  'patches_36.jpg',
#  'pitted_surface_228.jpg',
#  'inclusion_58.jpg',
#  'rolled-in_scale_239.jpg',
#  'crazing_219.jpg',
#  'pitted_surface_214.jpg',
#  'crazing_231.jpg',
#  'rolled-in_scale_205.jpg',
#  'inclusion_197.jpg',
#  'inclusion_64.jpg',
#  'inclusion_183.jpg',
#  'inclusion_70.jpg',
#  'crazing_225.jpg',
#  'rolled-in_scale_211.jpg',
#  'pitted_surface_200.jpg',
#  'inclusion_168.jpg',
#  'rolled-in_scale_18.jpg',
#  'rolled-in_scale_30.jpg',
#  'inclusion_154.jpg',
#  'inclusion_140.jpg',
#  'rolled-in_scale_24.jpg',
#  'patches_228.jpg',
#  'scratches_153.jpg',
#  'scratches_147.jpg',
#  'patches_214.jpg',
#  'patches_200.jpg',
#  'scratches_190.jpg',
#  'scratches_39.jpg',
#  'scratches_184.jpg',
#  'scratches_11.jpg',
#  'crazing_147.jpg',
#  'rolled-in_scale_173.jpg',
#  'pitted_surface_162.jpg',
#  'pitted_surface_176.jpg',
#  'crazing_153.jpg',
#  'rolled-in_scale_167.jpg',
#  'pitted_surface_189.jpg',
#  'rolled-in_scale_198.jpg',
#  'crazing_184.jpg',
#  'inclusion_222.jpg',
#  'inclusion_236.jpg',
#  'crazing_190.jpg',
#  'crazing_191.jpg',
#  'inclusion_237.jpg',
#  'inclusion_223.jpg',
#  'crazing_185.jpg',
#  'pitted_surface_188.jpg',
#  'rolled-in_scale_199.jpg',
#  'pitted_surface_177.jpg',
#  'rolled-in_scale_166.jpg',
#  'crazing_152.jpg',
#  'rolled-in_scale_172.jpg',
#  'crazing_146.jpg',
#  'pitted_surface_163.jpg',
#  'scratches_10.jpg',
#  'scratches_185.jpg',
#  'scratches_38.jpg',
#  'scratches_191.jpg',
#  'patches_201.jpg',
#  'patches_215.jpg',
#  'scratches_146.jpg',
#  'patches_229.jpg',
#  'scratches_152.jpg',
#  'inclusion_141.jpg',
#  'rolled-in_scale_25.jpg',
#  'rolled-in_scale_31.jpg',
#  'inclusion_155.jpg',
#  'rolled-in_scale_19.jpg',
#  'inclusion_169.jpg',
#  'rolled-in_scale_210.jpg',
#  'crazing_224.jpg',
#  'inclusion_71.jpg',
#  'inclusion_182.jpg',
#  'pitted_surface_201.jpg',
#  'pitted_surface_215.jpg',
#  'inclusion_65.jpg',
#  'inclusion_196.jpg',
#  'rolled-in_scale_204.jpg',
#  'crazing_230.jpg',
#  'crazing_218.jpg',
#  'pitted_surface_229.jpg',
#  'rolled-in_scale_238.jpg',
#  'inclusion_59.jpg',
#  'crazing_74.jpg',
#  'patches_37.jpg',
#  'patches_23.jpg',
#  'crazing_60.jpg',
#  'crazing_48.jpg',
#  'patches_188.jpg',
#  'crazing_9.jpg',
#  'patches_177.jpg',
#  'pitted_surface_12.jpg',
#  'scratches_218.jpg',
#  'patches_163.jpg',
#  'scratches_230.jpg',
#  'scratches_224.jpg',
#  'scratches_232.jpg',
#  'crazing_89.jpg',
#  'patches_149.jpg',
#  'pitted_surface_38.jpg',
#  'scratches_226.jpg',
#  'rolled-in_scale_9.jpg',
#  'patches_175.jpg',
#  'pitted_surface_10.jpg',
#  'patches_161.jpg',
#  'patches_35.jpg',
#  'crazing_76.jpg',
#  'crazing_62.jpg',
#  'patches_21.jpg',
#  'pitted_surface_203.jpg',
#  'inclusion_180.jpg',
#  'inclusion_73.jpg',
#  'crazing_226.jpg',
#  'rolled-in_scale_212.jpg',
#  'crazing_232.jpg',
#  'rolled-in_scale_206.jpg',
#  'inclusion_194.jpg',
#  'inclusion_67.jpg',
#  'pitted_surface_217.jpg',
#  'inclusion_98.jpg',
#  'rolled-in_scale_27.jpg',
#  'inclusion_143.jpg',
#  'inclusion_157.jpg',
#  'rolled-in_scale_33.jpg',
#  'scratches_144.jpg',
#  'scratches_150.jpg',
#  'patches_203.jpg',
#  'scratches_178.jpg',
#  'patches_217.jpg',
#  'scratches_187.jpg',
#  'scratches_193.jpg',
#  'scratches_12.jpg',
#  'rolled-in_scale_158.jpg',
#  'pitted_surface_149.jpg',
#  'crazing_178.jpg',
#  'crazing_150.jpg',
#  'rolled-in_scale_164.jpg',
#  'pitted_surface_175.jpg',
#  'pitted_surface_161.jpg',
#  'crazing_144.jpg',
#  'rolled-in_scale_170.jpg',
#  'inclusion_209.jpg',
#  'inclusion_235.jpg',
#  'crazing_193.jpg',
#  'crazing_187.jpg',
#  'inclusion_221.jpg',
#  'inclusion_220.jpg',
#  'crazing_186.jpg',
#  'crazing_192.jpg',
#  'inclusion_234.jpg',
#  'inclusion_208.jpg',
#  'pitted_surface_160.jpg',
#  'rolled-in_scale_171.jpg',
#  'crazing_145.jpg',
#  'rolled-in_scale_165.jpg',
#  'crazing_151.jpg',
#  'pitted_surface_174.jpg',
#  'crazing_179.jpg',
#  'rolled-in_scale_159.jpg',
#  'pitted_surface_148.jpg',
#  'scratches_13.jpg',
#  'scratches_192.jpg',
#  'scratches_186.jpg',
#  'patches_216.jpg',
#  'patches_202.jpg',
#  'scratches_179.jpg',
#  'scratches_151.jpg',
#  'scratches_145.jpg',
#  'inclusion_156.jpg',
#  'rolled-in_scale_32.jpg',
#  'rolled-in_scale_26.jpg',
#  'inclusion_142.jpg',
#  'inclusion_99.jpg',
#  'inclusion_66.jpg',
#  'inclusion_195.jpg',
#  'rolled-in_scale_207.jpg',
#  'crazing_233.jpg',
#  'pitted_surface_216.jpg',
#  'pitted_surface_202.jpg',
#  'rolled-in_scale_213.jpg',
#  'crazing_227.jpg',
#  'inclusion_72.jpg',
#  'inclusion_181.jpg',
#  'crazing_63.jpg',
#  'patches_20.jpg',
#  'patches_34.jpg',
#  'crazing_77.jpg',
#  'patches_160.jpg',
#  'pitted_surface_11.jpg',
#  'patches_174.jpg',
#  'pitted_surface_39.jpg',
#  'rolled-in_scale_8.jpg',
#  'scratches_227.jpg',
#  'scratches_233.jpg',
#  'patches_148.jpg',
#  'crazing_88.jpg',
#  'patches_170.jpg',
#  'pitted_surface_15.jpg',
#  'patches_164.jpg',
#  'pitted_surface_29.jpg',
#  'scratches_237.jpg',
#  'scratches_223.jpg',
#  'patches_158.jpg',
#  'crazing_98.jpg',
#  'crazing_73.jpg',
#  'patches_30.jpg',
#  'patches_24.jpg',
#  'crazing_67.jpg',
#  'patches_18.jpg',
#  'inclusion_185.jpg',
#  'inclusion_76.jpg',
#  'rolled-in_scale_217.jpg',
#  'crazing_223.jpg',
#  'pitted_surface_206.jpg',
#  'pitted_surface_212.jpg',
#  'rolled-in_scale_203.jpg',
#  'crazing_237.jpg',
#  'inclusion_191.jpg',
#  'inclusion_62.jpg',
#  'inclusion_146.jpg',
#  'rolled-in_scale_22.jpg',
#  'rolled-in_scale_36.jpg',
#  'inclusion_152.jpg',
#  'inclusion_89.jpg',
#  'patches_206.jpg',
#  'patches_212.jpg',
#  'scratches_169.jpg',
#  'scratches_141.jpg',
#  'scratches_155.jpg',
#  'scratches_17.jpg',
#  'scratches_182.jpg',
#  'scratches_196.jpg',
#  'pitted_surface_170.jpg',
#  'rolled-in_scale_161.jpg',
#  'crazing_155.jpg',
#  'rolled-in_scale_175.jpg',
#  'crazing_141.jpg',
#  'pitted_surface_164.jpg',
#  'crazing_169.jpg',
#  'rolled-in_scale_149.jpg',
#  'pitted_surface_158.jpg',
#  'patches_8.jpg',
#  'inclusion_230.jpg',
#  'crazing_196.jpg',
#  'crazing_182.jpg',
#  'inclusion_224.jpg',
#  'inclusion_218.jpg',
#  'inclusion_219.jpg',
#  'inclusion_225.jpg',
#  'crazing_183.jpg',
#  'patches_9.jpg',
#  'crazing_197.jpg',
#  'inclusion_231.jpg',
#  'rolled-in_scale_148.jpg',
#  'pitted_surface_159.jpg',
#  'crazing_168.jpg',
#  'crazing_140.jpg',
#  'rolled-in_scale_174.jpg',
#  'pitted_surface_165.jpg',
#  'pitted_surface_171.jpg',
#  'crazing_154.jpg',
#  'rolled-in_scale_160.jpg',
#  'scratches_197.jpg',
#  'scratches_183.jpg',
#  'scratches_16.jpg',
#  'scratches_154.jpg',
#  'scratches_140.jpg',
#  'patches_213.jpg',
#  'scratches_168.jpg',
#  'patches_207.jpg',
#  'inclusion_88.jpg',
#  'rolled-in_scale_37.jpg',
#  'inclusion_153.jpg',
#  'inclusion_147.jpg',
#  'rolled-in_scale_23.jpg',
#  'pitted_surface_213.jpg',
#  'inclusion_63.jpg',
#  'inclusion_190.jpg',
#  'crazing_236.jpg',
#  'rolled-in_scale_202.jpg',
#  'crazing_222.jpg',
#  'rolled-in_scale_216.jpg',
#  'inclusion_77.jpg',
#  'inclusion_184.jpg',
#  'pitted_surface_207.jpg',
#  'patches_19.jpg',
#  'patches_25.jpg',
#  'crazing_66.jpg',
#  'crazing_72.jpg',
#  'patches_31.jpg',
#  'scratches_222.jpg',
#  'crazing_99.jpg',
#  'patches_159.jpg',
#  'pitted_surface_28.jpg',
#  'scratches_236.jpg',
#  'patches_165.jpg',
#  'pitted_surface_14.jpg',
#  'patches_171.jpg',
#  'patches_167.jpg',
#  'scratches_208.jpg',
#  'pitted_surface_16.jpg',
#  'patches_173.jpg',
#  'scratches_220.jpg',
#  'scratches_234.jpg',
#  'crazing_64.jpg',
#  'patches_27.jpg',
#  'patches_33.jpg',
#  'crazing_70.jpg',
#  'crazing_58.jpg',
#  'patches_198.jpg',
#  'rolled-in_scale_200.jpg',
#  'crazing_234.jpg',
#  'inclusion_192.jpg',
#  'inclusion_61.jpg',
#  'pitted_surface_211.jpg',
#  'pitted_surface_205.jpg',
#  'inclusion_186.jpg',
#  'inclusion_75.jpg',
#  'rolled-in_scale_214.jpg',
#  'crazing_220.jpg',
#  'crazing_208.jpg',
#  'pitted_surface_239.jpg',
#  'rolled-in_scale_228.jpg',
#  'inclusion_49.jpg',
#  'inclusion_151.jpg',
#  'rolled-in_scale_35.jpg',
#  'rolled-in_scale_21.jpg',
#  'inclusion_145.jpg',
#  'inclusion_179.jpg',
#  'pitted_surface_9.jpg',
#  'patches_211.jpg',
#  'patches_205.jpg',
#  'scratches_156.jpg',
#  'patches_239.jpg',
#  'scratches_142.jpg',
#  'scratches_14.jpg',
#  'scratches_195.jpg',
#  'scratches_181.jpg',
#  'scratches_28.jpg',
#  'pitted_surface_167.jpg',
#  'rolled-in_scale_176.jpg',
#  'crazing_142.jpg',
#  'rolled-in_scale_162.jpg',
#  'crazing_156.jpg',
#  'pitted_surface_173.jpg',
#  'crazing_181.jpg',
#  'inclusion_227.jpg',
#  'inclusion_233.jpg',
#  'crazing_195.jpg',
#  'pitted_surface_198.jpg',
#  'rolled-in_scale_189.jpg',
#  'pitted_surface_199.jpg',
#  'rolled-in_scale_188.jpg',
#  'crazing_194.jpg',
#  'inclusion_232.jpg',
#  'inclusion_226.jpg',
#  'crazing_180.jpg',
#  'crazing_157.jpg',
#  'rolled-in_scale_163.jpg',
#  'pitted_surface_172.jpg',
#  'pitted_surface_166.jpg',
#  'crazing_143.jpg',
#  'rolled-in_scale_177.jpg',
#  'scratches_29.jpg',
#  'scratches_180.jpg',
#  'scratches_194.jpg',
#  'scratches_15.jpg',
#  'patches_238.jpg',
#  'scratches_143.jpg',
#  'scratches_157.jpg',
#  'patches_204.jpg',
#  'patches_210.jpg',
#  'pitted_surface_8.jpg',
#  'inclusion_178.jpg',
#  'rolled-in_scale_20.jpg',
#  'inclusion_144.jpg',
#  'inclusion_150.jpg',
#  'rolled-in_scale_34.jpg',
#  'pitted_surface_238.jpg',
#  'inclusion_48.jpg',
#  'rolled-in_scale_229.jpg',
#  'crazing_209.jpg',
#  'pitted_surface_204.jpg',
#  'crazing_221.jpg',
#  'rolled-in_scale_215.jpg',
#  'inclusion_74.jpg',
#  'inclusion_187.jpg',
#  'inclusion_60.jpg',
#  'inclusion_193.jpg',
#  'crazing_235.jpg',
#  'rolled-in_scale_201.jpg',
#  'pitted_surface_210.jpg',
#  'patches_199.jpg',
#  'crazing_59.jpg',
#  'patches_32.jpg',
#  'crazing_71.jpg',
#  'crazing_65.jpg',
#  'patches_26.jpg',
#  'scratches_235.jpg',
#  'scratches_221.jpg',
#  'scratches_209.jpg',
#  'patches_172.jpg',
#  'pitted_surface_17.jpg',
#  'patches_166.jpg',
#  'pitted_surface_58.jpg',
#  'scratches_246.jpg',
#  'scratches_5.jpg',
#  'scratches_252.jpg',
#  'patches_129.jpg',
#  'patches_101.jpg',
#  'pitted_surface_64.jpg',
#  'inclusion_9.jpg',
#  'patches_82.jpg',
#  'patches_96.jpg',
#  'patches_115.jpg',
#  'pitted_surface_70.jpg',
#  'scratches_285.jpg',
#  'patches_69.jpg',
#  'scratches_291.jpg',
#  'patches_41.jpg',
#  'patches_55.jpg',
#  'crazing_16.jpg',
#  'crazing_252.jpg',
#  'rolled-in_scale_266.jpg',
#  'pitted_surface_277.jpg',
#  'rolled-in_scale_90.jpg',
#  'rolled-in_scale_84.jpg',
#  'pitted_surface_263.jpg',
#  'crazing_246.jpg',
#  'rolled-in_scale_272.jpg',
#  'inclusion_13.jpg',
#  'rolled-in_scale_299.jpg',
#  'pitted_surface_288.jpg',
#  'crazing_291.jpg',
#  'inclusion_137.jpg',
#  'rolled-in_scale_53.jpg',
#  'rolled-in_scale_47.jpg',
#  'inclusion_123.jpg',
#  'crazing_285.jpg',
#  'scratches_99.jpg',
#  'scratches_130.jpg',
#  'scratches_124.jpg',
#  'patches_277.jpg',
#  'patches_263.jpg',
#  'scratches_118.jpg',
#  'patches_288.jpg',
#  'scratches_66.jpg',
#  'scratches_72.jpg',
#  'crazing_118.jpg',
#  'rolled-in_scale_138.jpg',
#  'pitted_surface_129.jpg',
#  'pitted_surface_101.jpg',
#  'crazing_124.jpg',
#  'rolled-in_scale_110.jpg',
#  'inclusion_282.jpg',
#  'inclusion_296.jpg',
#  'crazing_130.jpg',
#  'rolled-in_scale_104.jpg',
#  'pitted_surface_115.jpg',
#  'inclusion_269.jpg',
#  'inclusion_241.jpg',
#  'inclusion_255.jpg',
#  'inclusion_254.jpg',
#  'inclusion_240.jpg',
#  'inclusion_268.jpg',
#  'rolled-in_scale_105.jpg',
#  'crazing_131.jpg',
#  'inclusion_297.jpg',
#  'pitted_surface_114.jpg',
#  'pitted_surface_100.jpg',
#  'inclusion_283.jpg',
#  'rolled-in_scale_111.jpg',
#  'crazing_125.jpg',
#  'rolled-in_scale_139.jpg',
#  'pitted_surface_128.jpg',
#  'crazing_119.jpg',
#  'scratches_73.jpg',
#  'scratches_67.jpg',
#  'patches_289.jpg',
#  'patches_262.jpg',
#  'scratches_119.jpg',
#  'patches_276.jpg',
#  'scratches_125.jpg',
#  'scratches_131.jpg',
#  'scratches_98.jpg',
#  'rolled-in_scale_46.jpg',
#  'crazing_284.jpg',
#  'inclusion_122.jpg',
#  'inclusion_136.jpg',
#  'crazing_290.jpg',
#  'rolled-in_scale_52.jpg',
#  'rolled-in_scale_298.jpg',
#  'pitted_surface_289.jpg',
#  'pitted_surface_262.jpg',
#  'rolled-in_scale_85.jpg',
#  'inclusion_12.jpg',
#  'rolled-in_scale_273.jpg',
#  'crazing_247.jpg',
#  'rolled-in_scale_267.jpg',
#  'crazing_253.jpg',
#  'rolled-in_scale_91.jpg',
#  'pitted_surface_276.jpg',
#  'patches_54.jpg',
#  'crazing_17.jpg',
#  'patches_40.jpg',
#  'scratches_290.jpg',
#  'patches_68.jpg',
#  'scratches_284.jpg',
#  'patches_97.jpg',
#  'pitted_surface_71.jpg',
#  'patches_114.jpg',
#  'pitted_surface_65.jpg',
#  'patches_100.jpg',
#  'patches_83.jpg',
#  'inclusion_8.jpg',
#  'scratches_253.jpg',
#  'patches_128.jpg',
#  'pitted_surface_59.jpg',
#  'scratches_4.jpg',
#  'scratches_247.jpg',
#  'scratches_251.jpg',
#  'scratches_245.jpg',
#  'scratches_6.jpg',
#  'pitted_surface_73.jpg',
#  'patches_116.jpg',
#  'patches_95.jpg',
#  'scratches_279.jpg',
#  'patches_81.jpg',
#  'pitted_surface_67.jpg',
#  'patches_102.jpg',
#  'crazing_29.jpg',
#  'scratches_292.jpg',
#  'scratches_286.jpg',
#  'pitted_surface_98.jpg',
#  'crazing_15.jpg',
#  'patches_56.jpg',
#  'patches_42.jpg',
#  'crazing_279.jpg',
#  'pitted_surface_248.jpg',
#  'rolled-in_scale_259.jpg',
#  'inclusion_38.jpg',
#  'crazing_245.jpg',
#  'rolled-in_scale_271.jpg',
#  'inclusion_10.jpg',
#  'rolled-in_scale_87.jpg',
#  'pitted_surface_260.jpg',
#  'pitted_surface_274.jpg',
#  'patches_300.jpg',
#  'rolled-in_scale_93.jpg',
#  'crazing_251.jpg',
#  'rolled-in_scale_265.jpg',
#  'rolled-in_scale_78.jpg',
#  'inclusion_108.jpg',
#  'inclusion_120.jpg',
#  'crazing_286.jpg',
#  'rolled-in_scale_44.jpg',
#  'rolled-in_scale_50.jpg',
#  'crazing_292.jpg',
#  'inclusion_134.jpg',
#  'scratches_127.jpg',
#  'patches_248.jpg',
#  'scratches_133.jpg',
#  'patches_260.jpg',
#  'pitted_surface_300.jpg',
#  'patches_274.jpg',
#  'scratches_59.jpg',
#  'scratches_71.jpg',
#  'scratches_65.jpg',
#  'pitted_surface_116.jpg',
#  'inclusion_295.jpg',
#  'crazing_133.jpg',
#  'rolled-in_scale_107.jpg',
#  'crazing_127.jpg',
#  'rolled-in_scale_113.jpg',
#  'inclusion_281.jpg',
#  'pitted_surface_102.jpg',
#  'inclusion_256.jpg',
#  'inclusion_242.jpg',
#  'inclusion_243.jpg',
#  'inclusion_257.jpg',
#  'inclusion_280.jpg',
#  'rolled-in_scale_112.jpg',
#  'crazing_126.jpg',
#  'pitted_surface_103.jpg',
#  'pitted_surface_117.jpg',
#  'rolled-in_scale_106.jpg',
#  'crazing_132.jpg',
#  'inclusion_294.jpg',
#  'scratches_64.jpg',
#  'scratches_70.jpg',
#  'scratches_58.jpg',
#  'patches_275.jpg',
#  'patches_261.jpg',
#  'patches_249.jpg',
#  'scratches_132.jpg',
#  'scratches_126.jpg',
#  'rolled-in_scale_51.jpg',
#  'inclusion_135.jpg',
#  'crazing_293.jpg',
#  'crazing_287.jpg',
#  'inclusion_121.jpg',
#  'rolled-in_scale_45.jpg',
#  'inclusion_109.jpg',
#  'rolled-in_scale_79.jpg',
#  'rolled-in_scale_92.jpg',
#  'pitted_surface_275.jpg',
#  'rolled-in_scale_264.jpg',
#  'crazing_250.jpg',
#  'inclusion_11.jpg',
#  'rolled-in_scale_270.jpg',
#  'crazing_244.jpg',
#  'pitted_surface_261.jpg',
#  'rolled-in_scale_86.jpg',
#  'pitted_surface_249.jpg',
#  'inclusion_39.jpg',
#  'rolled-in_scale_258.jpg',
#  'crazing_278.jpg',
#  'patches_43.jpg',
#  'crazing_14.jpg',
#  'patches_57.jpg',
#  'scratches_287.jpg',
#  'pitted_surface_99.jpg',
#  'crazing_28.jpg',
#  'scratches_293.jpg',
#  'patches_80.jpg',
#  'scratches_278.jpg',
#  'patches_103.jpg',
#  'pitted_surface_66.jpg',
#  'patches_117.jpg',
#  'pitted_surface_72.jpg',
#  'patches_94.jpg',
#  'scratches_7.jpg',
#  'scratches_244.jpg',
#  'scratches_250.jpg',
#  'patches_90.jpg',
#  'scratches_268.jpg',
#  'pitted_surface_76.jpg',
#  'patches_113.jpg',
#  'pitted_surface_62.jpg',
#  'patches_107.jpg',
#  'patches_84.jpg',
#  'scratches_254.jpg',
#  'scratches_3.jpg',
#  'scratches_240.jpg',
#  'patches_53.jpg',
#  'crazing_10.jpg',
#  'patches_47.jpg',
#  'scratches_297.jpg',
#  'pitted_surface_89.jpg',
#  'crazing_38.jpg',
#  'scratches_283.jpg',
#  'rolled-in_scale_82.jpg',
#  'pitted_surface_265.jpg',
#  'rolled-in_scale_274.jpg',
#  'crazing_240.jpg',
#  'inclusion_15.jpg',
#  'rolled-in_scale_260.jpg',
#  'crazing_254.jpg',
#  'pitted_surface_271.jpg',
#  'rolled-in_scale_96.jpg',
#  'pitted_surface_259.jpg',
#  'inclusion_29.jpg',
#  'rolled-in_scale_248.jpg',
#  'crazing_268.jpg',
#  'rolled-in_scale_41.jpg',
#  'inclusion_125.jpg',
#  'crazing_283.jpg',
#  'crazing_297.jpg',
#  'inclusion_131.jpg',
#  'rolled-in_scale_55.jpg',
#  'inclusion_119.jpg',
#  'rolled-in_scale_69.jpg',
#  'patches_265.jpg',
#  'rolled-in_scale_300.jpg',
#  'patches_271.jpg',
#  'patches_259.jpg',
#  'scratches_122.jpg',
#  'scratches_136.jpg',
#  'scratches_74.jpg',
#  'scratches_60.jpg',
#  'scratches_48.jpg',
#  'inclusion_290.jpg',
#  'rolled-in_scale_102.jpg',
#  'crazing_136.jpg',
#  'pitted_surface_113.jpg',
#  'pitted_surface_107.jpg',
#  'rolled-in_scale_116.jpg',
#  'crazing_122.jpg',
#  'inclusion_284.jpg',
#  'inclusion_253.jpg',
#  'inclusion_247.jpg',
#  'inclusion_246.jpg',
#  'inclusion_252.jpg',
#  'pitted_surface_106.jpg',
#  'inclusion_285.jpg',
#  'crazing_123.jpg',
#  'rolled-in_scale_117.jpg',
#  'crazing_137.jpg',
#  'rolled-in_scale_103.jpg',
#  'inclusion_291.jpg',
#  'pitted_surface_112.jpg',
#  'scratches_49.jpg',
#  'scratches_61.jpg',
#  'scratches_75.jpg',
#  'scratches_137.jpg',
#  'patches_258.jpg',
#  'scratches_123.jpg',
#  'patches_270.jpg',
#  'patches_264.jpg',
#  'rolled-in_scale_68.jpg',
#  'inclusion_118.jpg',
#  'inclusion_130.jpg',
#  'crazing_296.jpg',
#  'rolled-in_scale_54.jpg',
#  'rolled-in_scale_40.jpg',
#  'crazing_282.jpg',
#  'inclusion_124.jpg',
#  'crazing_269.jpg',
#  'pitted_surface_258.jpg',
#  'rolled-in_scale_249.jpg',
#  'inclusion_28.jpg',
#  'crazing_255.jpg',
#  'rolled-in_scale_261.jpg',
#  'rolled-in_scale_97.jpg',
#  'pitted_surface_270.jpg',
#  'pitted_surface_264.jpg',
#  'rolled-in_scale_83.jpg',
#  'inclusion_14.jpg',
#  'crazing_241.jpg',
#  'rolled-in_scale_275.jpg',
#  'crazing_39.jpg',
#  'scratches_282.jpg',
#  'scratches_296.jpg',
#  'pitted_surface_88.jpg',
#  'patches_46.jpg',
#  'patches_52.jpg',
#  'crazing_11.jpg',
#  'scratches_241.jpg',
#  'scratches_2.jpg',
#  'scratches_255.jpg',
#  'patches_106.jpg',
#  'pitted_surface_63.jpg',
#  'patches_85.jpg',
#  'scratches_269.jpg',
#  'patches_91.jpg',
#  'patches_112.jpg',
#  'pitted_surface_77.jpg',
#  'patches_87.jpg',
#  'patches_104.jpg',
#  'pitted_surface_61.jpg',
#  'patches_110.jpg',
#  'pitted_surface_75.jpg',
#  'patches_93.jpg',
#  'scratches_243.jpg',
#  'patches_138.jpg',
#  'pitted_surface_49.jpg',
#  'scratches_257.jpg',
#  'patches_44.jpg',
#  'crazing_13.jpg',
#  'patches_50.jpg',
#  'scratches_280.jpg',
#  'patches_78.jpg',
#  'scratches_294.jpg',
#  'pitted_surface_272.jpg',
#  'rolled-in_scale_95.jpg',
#  'rolled-in_scale_263.jpg',
#  'crazing_257.jpg',
#  'rolled-in_scale_277.jpg',
#  'crazing_243.jpg',
#  'inclusion_16.jpg',
#  'rolled-in_scale_81.jpg',
#  'pitted_surface_266.jpg',
#  'rolled-in_scale_56.jpg',
#  'crazing_294.jpg',
#  'inclusion_132.jpg',
#  'inclusion_126.jpg',
#  'crazing_280.jpg',
#  'rolled-in_scale_42.jpg',
#  'rolled-in_scale_288.jpg',
#  'pitted_surface_299.jpg',
#  'patches_272.jpg',
#  'scratches_109.jpg',
#  'patches_266.jpg',
#  'scratches_135.jpg',
#  'scratches_88.jpg',
#  'scratches_121.jpg',
#  'scratches_63.jpg',
#  'scratches_77.jpg',
#  'patches_299.jpg',
#  'rolled-in_scale_115.jpg',
#  'crazing_121.jpg',
#  'inclusion_287.jpg',
#  'pitted_surface_104.jpg',
#  'pitted_surface_110.jpg',
#  'inclusion_293.jpg',
#  'rolled-in_scale_101.jpg',
#  'crazing_135.jpg',
#  'rolled-in_scale_129.jpg',
#  'pitted_surface_138.jpg',
#  'crazing_109.jpg',
#  'inclusion_244.jpg',
#  'inclusion_250.jpg',
#  'inclusion_278.jpg',
#  'inclusion_279.jpg',
#  'inclusion_251.jpg',
#  'inclusion_245.jpg',
#  'crazing_108.jpg',
#  'rolled-in_scale_128.jpg',
#  'pitted_surface_139.jpg',
#  'pitted_surface_111.jpg',
#  'crazing_134.jpg',
#  'rolled-in_scale_100.jpg',
#  'inclusion_292.jpg',
#  'inclusion_286.jpg',
#  'crazing_120.jpg',
#  'rolled-in_scale_114.jpg',
#  'pitted_surface_105.jpg',
#  'patches_298.jpg',
#  'scratches_76.jpg',
#  'scratches_62.jpg',
#  'scratches_120.jpg',
#  'scratches_89.jpg',
#  'scratches_134.jpg',
#  'patches_267.jpg',
#  'patches_273.jpg',
#  'scratches_108.jpg',
#  'rolled-in_scale_289.jpg',
#  'pitted_surface_298.jpg',
#  'crazing_281.jpg',
#  'inclusion_127.jpg',
#  'rolled-in_scale_43.jpg',
#  'rolled-in_scale_57.jpg',
#  'inclusion_133.jpg',
#  'crazing_295.jpg',
#  'inclusion_17.jpg',
#  'crazing_242.jpg',
#  'rolled-in_scale_276.jpg',
#  'pitted_surface_267.jpg',
#  'rolled-in_scale_80.jpg',
#  'rolled-in_scale_94.jpg',
#  'pitted_surface_273.jpg',
#  'crazing_256.jpg',
#  'rolled-in_scale_262.jpg',
#  'scratches_295.jpg',
#  'patches_79.jpg',
#  'scratches_281.jpg',
#  'crazing_12.jpg',
#  'patches_51.jpg',
#  'patches_45.jpg',
#  'pitted_surface_48.jpg',
#  'scratches_256.jpg',
#  'scratches_242.jpg',
#  'scratches_1.jpg',
#  'patches_139.jpg',
#  'pitted_surface_74.jpg',
#  'patches_111.jpg',
#  'patches_92.jpg',
#  'patches_86.jpg',
#  'pitted_surface_60.jpg',
#  'patches_105.jpg',
#  'pitted_surface_79.jpg',
#  'scratches_267.jpg',
#  'scratches_273.jpg',
#  'patches_108.jpg',
#  'patches_120.jpg',
#  'pitted_surface_45.jpg',
#  'patches_134.jpg',
#  'pitted_surface_51.jpg',
#  'patches_48.jpg',
#  'pitted_surface_86.jpg',
#  'crazing_23.jpg',
#  'scratches_298.jpg',
#  'patches_60.jpg',
#  'inclusion_300.jpg',
#  'patches_74.jpg',
#  'crazing_37.jpg',
#  'pitted_surface_92.jpg',
#  'rolled-in_scale_99.jpg',
#  'crazing_273.jpg',
#  'rolled-in_scale_247.jpg',
#  'inclusion_26.jpg',
#  'pitted_surface_256.jpg',
#  'pitted_surface_242.jpg',
#  'inclusion_32.jpg',
#  'crazing_267.jpg',
#  'rolled-in_scale_253.jpg',
#  'crazing_298.jpg',
#  'inclusion_116.jpg',
#  'rolled-in_scale_284.jpg',
#  'pitted_surface_295.jpg',
#  'rolled-in_scale_72.jpg',
#  'rolled-in_scale_66.jpg',
#  'pitted_surface_281.jpg',
#  'rolled-in_scale_290.jpg',
#  'inclusion_102.jpg',
#  'scratches_111.jpg',
#  'scratches_105.jpg',
#  'scratches_84.jpg',
#  'patches_256.jpg',
#  'patches_242.jpg',
#  'scratches_90.jpg',
#  'scratches_139.jpg',
#  'scratches_47.jpg',
#  'patches_295.jpg',
#  'patches_281.jpg',
#  'scratches_53.jpg',
#  'crazing_139.jpg',
#  'rolled-in_scale_119.jpg',
#  'pitted_surface_108.jpg',
#  'pitted_surface_120.jpg',
#  'crazing_105.jpg',
#  'rolled-in_scale_131.jpg',
#  'crazing_111.jpg',
#  'rolled-in_scale_125.jpg',
#  'pitted_surface_134.jpg',
#  'inclusion_248.jpg',
#  'inclusion_260.jpg',
#  'inclusion_274.jpg',
#  'inclusion_275.jpg',
#  'inclusion_261.jpg',
#  'inclusion_249.jpg',
#  'rolled-in_scale_124.jpg',
#  'crazing_110.jpg',
#  'pitted_surface_135.jpg',
#  'pitted_surface_121.jpg',
#  'rolled-in_scale_130.jpg',
#  'crazing_104.jpg',
#  'rolled-in_scale_118.jpg',
#  'pitted_surface_109.jpg',
#  'crazing_138.jpg',
#  'patches_280.jpg',
#  'scratches_52.jpg',
#  'scratches_46.jpg',
#  'patches_294.jpg',
#  'patches_243.jpg',
#  'scratches_138.jpg',
#  'scratches_91.jpg',
#  'scratches_85.jpg',
#  'patches_257.jpg',
#  'scratches_104.jpg',
#  'scratches_110.jpg',
#  'pitted_surface_280.jpg',
#  'rolled-in_scale_67.jpg',
#  'inclusion_103.jpg',
#  'rolled-in_scale_291.jpg',
#  'rolled-in_scale_285.jpg',
#  'inclusion_117.jpg',
#  'rolled-in_scale_73.jpg',
#  'pitted_surface_294.jpg',
#  'crazing_299.jpg',
#  'pitted_surface_243.jpg',
#  'rolled-in_scale_252.jpg',
#  'crazing_266.jpg',
#  'inclusion_33.jpg',
#  'inclusion_27.jpg',
#  'rolled-in_scale_246.jpg',
#  'crazing_272.jpg',
#  'pitted_surface_257.jpg',
#  'rolled-in_scale_98.jpg',
#  'patches_75.jpg',
#  'pitted_surface_93.jpg',
#  'crazing_36.jpg',
#  'crazing_22.jpg',
#  'pitted_surface_87.jpg',
#  'patches_61.jpg',
#  'scratches_299.jpg',
#  'patches_49.jpg',
#  'pitted_surface_50.jpg',
#  'patches_135.jpg',
#  'pitted_surface_44.jpg',
#  'patches_121.jpg',
#  'scratches_272.jpg',
#  'inclusion_1.jpg',
#  'patches_109.jpg',
#  'pitted_surface_78.jpg',
#  'scratches_266.jpg',
#  'patches_88.jpg',
#  'inclusion_3.jpg',
#  'scratches_270.jpg',
#  'scratches_264.jpg',
#  'pitted_surface_52.jpg',
#  'patches_137.jpg',
#  'scratches_258.jpg',
#  'pitted_surface_46.jpg',
#  'patches_123.jpg',
#  'crazing_34.jpg',
#  'pitted_surface_91.jpg',
#  'patches_77.jpg',
#  ...]

# %%
from xml.etree import ElementTree as ET
xml_path = '/Users/jakechiu/Desktop/NEU-DET/ANNOTATIONS/'
xml_name = os.listdir(xml_path) 
xml_list = []
for name in xml_name:
    b = []
    tree = ET.parse(xml_path + name)
    root = tree.getroot()
    n = root.find('filename').text
    if n.endswith('.jpg') == False:
        n = n + '.jpg'

    for size in root.findall('size'):
        w = int(size.find('width').text)
        h = int(size.find('height').text)
        d = int(size.find('depth').text)
    for ob in root.findall('object'):
        na = ob.find('name').text
        for bd in ob.findall('bndbox'):
            xmin = bd.find('xmin').text
            ymin = bd.find('ymin').text
            xmax = bd.find('xmax').text
            ymax = bd.find('ymax').text
        bndbox = (int(xmin), int(ymin), int(xmax), int(ymax))
        
        b.append([na,bndbox])
    xml_list.append([n, w, h, d, b])
    #xml_list.append({'name': n, 'width': w, 'height': h, 'depth': d, 'bndbox':b})

# %%
#Print first five objects
xml_list[:5]
# Out:
# [['crazing_61.jpg',
#   200,
#   200,
#   1,
#   [['crazing', (74, 103, 198, 166)], ['crazing', (28, 30, 179, 95)]]],
#  ['patches_22.jpg',
#   200,
#   200,
#   1,
#   [['patches', (10, 148, 57, 200)], ['patches', (109, 1, 179, 200)]]],
#  ['patches_36.jpg',
#   200,
#   200,
#   1,
#   [['patches', (16, 101, 70, 135)], ['patches', (109, 5, 164, 199)]]],
#  ['crazing_75.jpg',
#   200,
#   200,
#   1,
#   [['crazing', (4, 54, 147, 161)], ['crazing', (158, 24, 200, 173)]]],
#  ['crazing_8.jpg',
#   200,
#   200,
#   1,
#   [['crazing', (1, 26, 179, 118)], ['crazing', (1, 121, 176, 200)]]]]

# %%
for i in xml_list:
    ty = []
    for defect in i[4]:
        de = defect[0]
        if de not in ty:
            ty.append(de)
    #print ('{} has {} defect(s)'.format(i[0], len(i[4])))    
    #print ('{} has {} type of defects: {}'.format(i[0], len(ty), ty))
    #print('----------------------------------')

# %%
one, two, three, four, five, six, seven, more_than_seven = 0, 0, 0, 0, 0, 0, 0, 0

for i in xml_list:
    if len(i[4]) == 1:
        one += 1
    elif len(i[4]) == 2:
        two += 1
    elif len(i[4]) == 3:
        three += 1
    elif len(i[4]) == 4:
        four += 1
    elif len(i[4]) == 5:
        five += 1
    elif len(i[4]) == 6:
        six += 1
    elif len(i[4]) == 7:
        seven += 1
    else:
        more_than_seven += 1

names = ['1', '2', '3', '4', '5', '6', '7', '> 7']
values = [one, two, three, four, five, six, seven, more_than_seven]
plt.bar(names, values, color = ['r', 'g', 'b', 'c', 'm', 'y', 'k', '#7E2F8E'])
plt.title('Number(s) of Defects Within An Image')
plt.xlabel('Number(s) of Defects')
plt.ylabel('Frequency')
#for i in range(len(names)):
#    plt.text(x = r4[i]-0.5 , y = bars4[i]+0.1, s = label[i], size = 6)
plt.show()

for i in range(len(names)):
    print('{} Defect(s) in an image: {}'.format(names[i], values[i]))
# Out:
# 1 Defect(s) in an image: 483
# 2 Defect(s) in an image: 673
# 3 Defect(s) in an image: 390
# 4 Defect(s) in an image: 154
# 5 Defect(s) in an image: 59
# 6 Defect(s) in an image: 22
# 7 Defect(s) in an image: 9
# > 7 Defect(s) in an image: 10

# %%
One, Two, Three = 0, 0, 0

for i in xml_list:
    ty = []
    for defect in i[4]:
        de = defect[0]
        if de not in ty:
            ty.append(de)
            
    if len(ty) == 1:
        One += 1
    elif len(ty) == 2:
        Two += 1
    elif len(ty) == 3:
        Three += 1
    else: 
        more_than_three += 1

names = ['1', '2', '3']
values = [One, Two, Three]

plt.bar(names, values, color = ['r', 'g', 'b'])
plt.title('Type(s) of Defects Within An Image')
plt.xlabel('Type(s) of Defects')
plt.ylabel('Frequency')
plt.show()

for i in range(len(names)):
    print ('{} Type(s) of Defects in An Image: {}'.format(names[i], values[i]))
# Out:
# 1 Type(s) of Defects in An Image: 1677
# 2 Type(s) of Defects in An Image: 121
# 3 Type(s) of Defects in An Image: 2

# %%
Crazing, Inclusion, Patches, Scratches, Pitted_Surface, Rolled_In_Scale  = 0, 0, 0, 0, 0, 0
for i in xml_list:
    for defect in i[4]:
        de = defect[0]
        if de == 'crazing':
            Crazing += 1
        elif de == 'inclusion':
            Inclusion += 1
        elif de == 'patches':
            Patches += 1
        elif de == 'scratches':
            Scratches += 1
        elif de == 'pitted_surface':
            Pitted_Surface += 1
        else:
            Rolled_In_Scale += 1

Total = Crazing + Inclusion + Patches + Scratches + Pitted_Surface + Rolled_In_Scale
print('crazing:', Crazing)
print('inclusion:', Inclusion)
print('patches:', Patches)
print('scratches:', Scratches)
print('pitted_surface:', Pitted_Surface)
print('rolled_in scale:', Rolled_In_Scale)
print('Total Numbers of Defects:', Total)
# Out:
# crazing: 689
# inclusion: 1011
# patches: 881
# scratches: 548
# pitted_surface: 432
# rolled_in scale: 628
# Total Numbers of Defects: 4189

# %%
names = ['Crazing', 'Inclusion', 'Patches', 'Scratches', 'Pitted_Surface', 'Rolled_In_Scale']
values = [Crazing, Inclusion, Patches, Scratches, Pitted_Surface, Rolled_In_Scale]
plt.bar(names, values, color = ['r', 'g', 'b', 'c', 'm', 'y'])
plt.title('Frequency of Defects In the Dataset')
plt.xlabel('Number of Defects')
plt.xticks(rotation=90)
plt.ylabel('Frequency')
#for i in range(len(names)):
#    plt.text(x = r4[i]-0.5 , y = bars4[i]+0.1, s = label[i], size = 6)
plt.show()

# %% [markdown]
# ## Generate the Data

# %%
import sys
import io
import pandas as pd
import numpy as np
from PIL import Image
import IPython.display as display
import random
from sklearn.model_selection import train_test_split

# %%
def _int64_feature(value):
  return tf.train.Feature(int64_list = tf.train.Int64List(value = [value]))

def _floats_feature(value):
  return tf.train.Feature(float_list = tf.train.FloatList(value = [value]))

def _bytes_feature(value):
  return tf.train.Feature(bytes_list = tf.train.BytesList(value = [value]))

# %%
tfrecords = []
for name in img_name: 
    for i in xml_list:
        if name == i[0]:
            h = i[1]
            w = i[2]
            d = i[3]
            for defect in i[4]:
                xmin, ymin, xmax, ymax = defect[1][0], defect[1][1], defect[1][2], defect[1][3]
                tfrecords.append([name, h, w, d, defect[0], xmin, ymin, xmax, ymax])
tfrecords[:10]
# Out:
# [['scratches_225.jpg', 200, 200, 1, 'scratches', 53, 52, 70, 155],
#  ['scratches_225.jpg', 200, 200, 1, 'scratches', 173, 1, 186, 86],
#  ['scratches_225.jpg', 200, 200, 1, 'scratches', 162, 137, 182, 198],
#  ['scratches_225.jpg', 200, 200, 1, 'scratches', 1, 3, 16, 184],
#  ['scratches_225.jpg', 200, 200, 1, 'inclusion', 174, 179, 199, 200],
#  ['scratches_231.jpg', 200, 200, 1, 'scratches', 13, 1, 45, 195],
#  ['scratches_231.jpg', 200, 200, 1, 'scratches', 145, 3, 160, 200],
#  ['scratches_231.jpg', 200, 200, 1, 'scratches', 185, 1, 194, 199],
#  ['scratches_231.jpg', 200, 200, 1, 'inclusion', 12, 120, 100, 151],
#  ['scratches_219.jpg', 200, 200, 1, 'scratches', 83, 4, 99, 117]]

# %%
random.seed(2020)
random.shuffle(tfrecords)
n = Total//4
l = [tfrecords[x:x+n] for x in range(0, len(tfrecords), n)]
tf_dict = {'tf_1':l[0], 'tf_2':l[1], 'tf_3':l[2], 'tf_4':l[3] + l[4]}

# %%
tf_path = '/Users/jakechiu/Desktop/NEU-DET/tfrecord_1/'

for key, values in tf_dict.items():
    file = tf_path + key + '.tfrecords'
    print("Create files: ", key + '.tfrecords')
    writer = tf.io.TFRecordWriter(file)
    for record in values:
        image_path = path + record[0]
        image = skimg.imread(image_path)
        image_raw = image.tostring()
        example = tf.train.Example(features=tf.train.Features(feature={
            'image_raw': _bytes_feature(image_raw),
            'height': _int64_feature(record[1]),
            'width': _int64_feature(record[2]),
            'depth': _int64_feature(record[3]),
            'label': _bytes_feature(record[4].encode()),
            'xmin': _floats_feature(record[5]),
            'ymin': _floats_feature(record[6]),
            'xmax': _floats_feature(record[7]),
            'ymax': _floats_feature(record[8])}))
        writer.write(example.SerializeToString())
    writer.close()
# Out:
# /Users/jakechiu/Desktop/NEU-DET/tfrecord_1/tf_1.tfrecords
# /Users/jakechiu/Desktop/NEU-DET/tfrecord_1/tf_2.tfrecords
# /Users/jakechiu/Desktop/NEU-DET/tfrecord_1/tf_3.tfrecords
# /Users/jakechiu/Desktop/NEU-DET/tfrecord_1/tf_4.tfrecords

# %%
#reader = tf.TFRecordReader()
#queue = tf.train.string_input_producer('/Users/jakechiu/Desktop/NEU-DET/tfrecord/crazing_1-crazing.tfrecords')
#_, serialized = reader.read(queue)

# Create a dictionary describing the features.
#read_features = {
#    'image_raw': tf.io.FixedLenFeature([], tf.string),
#    'height': tf.io.FixedLenFeature([], tf.int64),
#    'width': tf.io.FixedLenFeature([], tf.int64),
#    'depth': tf.io.FixedLenFeature([], tf.int64),
#    'label': tf.io.FixedLenFeature([], tf.string),
#    'xmin': tf.io.FixedLenFeature([], tf.float32),
#    'ymin': tf.io.FixedLenFeature([], tf.float32),
#    'xmax': tf.io.FixedLenFeature([], tf.float32),
#    'ymax': tf.io.FixedLenFeature([], tf.float32)
#}

#features = tf.parse_single_example(serialied, read_features)
#image = features['image_raw']

# %%
for elem in parsed_image_dataset:
  print(elem['image_raw'])
#image = tf.io.read_file(filename)
#image = tf.image.decode_jpeg(image)
#image = tf.image.convert_image_dtype(image, tf.float32)
#image = tf.image.resize(image, [128, 128])
#image_raw = parsed_image_dataset['image_raw'].numpy()
#image = tf.image.decode_image(parsed_image_dataset['image_raw'], dtype=tf.float32) 
#display.display(display.Image(data=image_raw))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-793917fd2c69> in <module>
# ----> 1 for elem in parsed_image_dataset:
#       2   print(elem['image_raw'])
#       3 #image = tf.io.read_file(filename)
#       4 #image = tf.image.decode_jpeg(image)
#       5 #image = tf.image.convert_image_dtype(image, tf.float32)
#
# NameError: name 'parsed_image_dataset' is not defined

# %%
#IMAGE_SIZE = 200
#IMAGE_PIXELS = IMAGE_SIZE * IMAGE_SIZE
#for img in parsed_image_dataset:
#    image = tf.io.decode_raw(img['image_raw'], tf.uint8)
#    image.set_shape((IMAGE_PIXELS))
#    display.display(display.Image(data=image))
#    plt.figure()
#    plt.imshow(image)
#    plt.show()

# %%
#img['image_raw']
